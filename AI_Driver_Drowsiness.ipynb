# %% [markdown]
# <a href="https://colab.research.google.com/github/Asmita1109/Driver-Drowsiness/blob/main/AI_Driver_Drowsiness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
yasharjebraeily_drowsy_detection_dataset_path = kagglehub.dataset_download('yasharjebraeily/drowsy-detection-dataset')

print('Data source import complete.')

# %% [markdown]
# # Loading The Necessary Packages and Libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
import hashlib  # Used to generate and compare unique hash values (useful for detecting duplicate images)
from collections import defaultdict  # Efficient default dictionary structure for grouping and counting
import matplotlib.pyplot as plt  # Data visualization - plotting basic charts
import seaborn as sns  # Advanced statistical data visualization
from PIL import Image  # Image processing: opening, manipulating, and saving images
import cv2  # OpenCV library: powerful image and video processing
import tensorflow as tf  # TensorFlow core framework for deep learning
from tensorflow.keras.preprocessing.image import ImageDataGenerator  # Image preprocessing utility in Keras (part of TensorFlow), supports augmentation
# Out:
# 2025-05-07 19:12:38.113153: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746645158.467574      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746645158.560839      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # Dataset Loading : Path Setup

# %%
# Defining the path to the training and test data directory
train_data_dir = os.path.join('/kaggle/input/drowsy-detection-dataset/Drowsy_datset/train')
test_data_dir = os.path.join('/kaggle/input/drowsy-detection-dataset/Drowsy_datset/test')

# Listing all subdirectories (classes) or files present in the training and test folder
training_files = os.listdir(train_data_dir)
testing_files = os.listdir(test_data_dir)

# %%
print("Training data path :", train_data_dir)
print("Testing data path :", test_data_dir)
print("Train files :", training_files)
print("Test files :", testing_files)
# Out:
# Training data path : /kaggle/input/drowsy-detection-dataset/Drowsy_datset/train
# Testing data path : /kaggle/input/drowsy-detection-dataset/Drowsy_datset/test
# Train files : ['DROWSY', 'NATURAL']
# Test files : ['DROWSY', 'NATURAL']

# %%
train_drowsy_image_path = os.path.join(train_data_dir , 'DROWSY')
train_natural_image_path = os.path.join(train_data_dir, 'NATURAL')
train_drowsy_images= os.listdir(train_drowsy_image_path)
train_natural_images= os.listdir(train_natural_image_path)

test_drowsy_image_path = os.path.join(test_data_dir , 'DROWSY')
test_natural_image_path = os.path.join(test_data_dir, 'NATURAL')
test_drowsy_images= os.listdir(test_drowsy_image_path)
test_natural_images= os.listdir(test_natural_image_path)

print(f" Number of files in the training dataset as per class")
print(f" No of image files in the DROWSY train folder : {len(train_drowsy_images)}")
print(f" No of image files in the NATURAL test folder : {len(train_natural_images)} ")
print("\n Number of files in the testing dataset as per class ")
print(f" No of image files in the DROWSY train folder : {len(test_drowsy_images)}")
print(f" No of image files in the NATURAL test folder : {len(test_natural_images)} ")
# Out:
#  Number of files in the training dataset as per class
#  No of image files in the DROWSY train folder : 2809
#  No of image files in the NATURAL test folder : 3050
#
#  Number of files in the testing dataset as per class
#  No of image files in the DROWSY train folder : 757
#  No of image files in the NATURAL test folder : 726

# %% [markdown]
# # Copy Dataset to Working Directory (Kaggle)

# %%
import shutil

# Copy the entire dataset folder from the input directory to the working directory
shutil.copytree('/kaggle/input/drowsy-detection-dataset/Drowsy_datset',
                '/kaggle/working/Drowsy_datset', dirs_exist_ok=True)

# Defining new path for training and testing data inside the working directory
train_path = '/kaggle/working/Drowsy_datset/train'
test_path = '/kaggle/working/Drowsy_datset/test'

# %% [markdown]
# # Identifying and Deleting Duplicate Images

# %%
def get_md5(filepath):
    with open(filepath, 'rb') as f:
        return hashlib.md5(f.read()).hexdigest()

def remove_duplicates(folder_path):
    hash_map = defaultdict(list)
    total_removed = 0

    for subfolder in os.listdir(folder_path):
        subfolder_path = os.path.join(folder_path, subfolder)
        if not os.path.isdir(subfolder_path):
            continue

        for filename in os.listdir(subfolder_path):
            file_path = os.path.join(subfolder_path, filename)
            try:
                file_hash = get_md5(file_path)
                hash_map[file_hash].append(file_path)
            except Exception as e:
                print(f"Error reading {file_path}: {e}")

    for duplicates in hash_map.values():
        if len(duplicates) > 1:
            for dup in duplicates[1:]:  # Keep first
                try:
                    os.remove(dup)
                    print(f"Deleted: {dup}")
                    total_removed += 1
                except Exception as e:
                    print(f"Could not delete {dup}: {e}")

    print(f"✅ Deleted {total_removed} duplicate images.")

# Call on copied folders
remove_duplicates(train_path)
# Out:
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/163.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/166.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/170.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/169.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/171.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/168.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1989.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1968.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1420.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2012.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1389.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1454.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1492.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1417.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1427.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1440.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2047.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1494.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2034.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1947.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1515.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1988.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1496.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1503.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1539.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1990.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1913.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1416.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1955.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1914.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1941.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1939.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2059.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1499.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1538.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1528.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2064.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1405.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1551.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1513.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1907.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1954.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2001.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1992.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1392.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1934.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1959.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1475.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2000.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2043.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1949.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1385.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1456.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1559.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1908.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1906.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1963.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1421.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2010.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2063.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1555.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1545.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1991.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1380.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1463.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1980.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2015.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2026.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2035.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1425.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1460.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1534.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1532.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1972.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1526.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1997.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1473.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1448.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2077.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1919.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1903.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1910.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1467.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1962.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1394.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1944.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1519.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1411.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1501.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1378.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1468.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2031.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1436.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1485.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1433.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1936.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2067.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1543.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1477.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1945.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1412.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1923.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1446.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1974.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2005.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1560.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1550.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2003.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2062.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2056.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1441.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1465.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1419.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1457.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1509.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2073.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2008.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1893.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1976.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1942.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2021.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1408.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1558.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1912.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1996.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1986.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1953.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2050.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1484.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2017.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1960.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1969.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1529.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1523.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1504.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2007.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2057.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1920.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1455.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2018.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1514.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1896.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1932.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1897.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1438.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1379.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1535.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1925.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2027.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1512.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2071.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2016.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1469.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1520.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1527.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1993.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1474.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1518.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2054.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1952.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1940.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2046.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1961.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1566.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1471.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2020.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1382.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1530.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1542.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1898.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1971.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1891.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1564.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1998.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1938.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1982.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1562.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2075.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1900.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1556.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1407.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2051.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1905.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1418.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1911.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1548.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1489.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1423.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1531.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1391.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1384.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1909.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1406.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/2032.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1924.png
# Deleted: /kaggle/working/Drowsy_datset/train/DROWSY/1957.png
# Deleted: /kaggle/working/Drowsy_datset/train/NATURAL/143.png
# Deleted: /kaggle/working/Drowsy_datset/train/NATURAL/1040.png
# Deleted: /kaggle/working/Drowsy_datset/train/NATURAL/918.png
# Deleted: /kaggle/working/Drowsy_datset/train/NATURAL/1298.png
# Deleted: /kaggle/working/Drowsy_datset/train/NATURAL/268.png
# ✅ Deleted 201 duplicate images.

# %%
train_drowsy_image_path = os.path.join(train_path, 'DROWSY')
train_natural_image_path = os.path.join(train_path, 'NATURAL')
train_drowsy_images= os.listdir(train_drowsy_image_path)
train_natural_images= os.listdir(train_natural_image_path)

print(f" Number of files in the training dataset as per class")
print(f" No of image files in the DROWSY train folder : {len(train_drowsy_images)}")
print(f" No of image files in the NATURAL test folder : {len(train_natural_images)} ")
# Out:
#  Number of files in the training dataset as per class
#  No of image files in the DROWSY train folder : 2613
#  No of image files in the NATURAL test folder : 3045

# %% [markdown]
# # Bar Chart to Display No.of Images in each Category

# %%
# Count images in each subfolder (class)
class_counts = {}
for class_name in os.listdir(train_path):
    class_folder = os.path.join(train_path, class_name)
    if os.path.isdir(class_folder):
        image_count = len(os.listdir(class_folder))
        class_counts[class_name.upper()] = image_count  # Capitalize for display

# Plotting
plt.figure(figsize=(6,4))
plt.bar(class_counts.keys(), class_counts.values(), color=['red', 'green'])
plt.title('Image Count per Class')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # Displaying few sample images from Dataset

# %%
fig, axes = plt.subplots(4, 5, figsize=(15, 10))

for i, axes in enumerate(axes.flat):
    if i < 5:
        img = cv2.imread(os.path.join(train_drowsy_image_path, train_drowsy_images[i]))
        axes.imshow(img)
        axes.set_title('drowsy (train)')
    if i > 4 and i < 10:
        img = cv2.imread(os.path.join(train_natural_image_path, train_natural_images[i]))
        axes.imshow(img)
        axes.set_title('natural (train)')
    if i > 9 and i < 15:
        img = cv2.imread(os.path.join(test_drowsy_image_path, test_drowsy_images[i]))
        axes.imshow(img)
        axes.set_title('drowsy (test)')
    if i > 14 and i < 20:
        img = cv2.imread(os.path.join(test_natural_image_path, test_natural_images[i]))
        axes.imshow(img)
        axes.set_title('natural (test)')
plt.subplots_adjust(hspace=0.5)
plt.show()

# %% [markdown]
# #

# %% [markdown]
# # Splitting the Data

# %%
data_generator = ImageDataGenerator(
    rescale = 1./255.0,                   # Normalize pixel values to [0, 1]
    validation_split = 0.2,               # Reserve 20% of data for validation
    rotation_range=20,                    # Randomly rotate images up to 20 degrees
    width_shift_range=0.2,                # Random horizontal shift
    height_shift_range=0.2,               # Random vertical shift
    shear_range=0.2,                      # Shearing transformation
    zoom_range=0.2,                       # Random zoom within range
    horizontal_flip=True,                 # Randomly flip images horizontally
    fill_mode='nearest'                   # Fill in pixels after transformation
)

test_data_generator = ImageDataGenerator(
    rescale= 1./255.0,
)

# Training data generator: loads images from the 'train' folder (80% of total)
train_data_gen = data_generator.flow_from_directory(
    train_path,
    target_size=(224,224),
    class_mode='binary',
    batch_size= 32,
    subset='training',
    shuffle=True
)

# Validation data generator: loads the remaining 20% of training images
val_data_gen = data_generator.flow_from_directory(
    train_path,
    target_size=(224,224),
    class_mode='binary',
    batch_size=32,
    subset='validation',       # Use validation subset
    shuffle=True
)

# Test data generator: loads images from the test folder
test_data_gen = test_data_generator.flow_from_directory(
    test_path,
    target_size = (224,224),
    class_mode = 'binary',
    batch_size = 32,
    shuffle=True
)
# Out:
# Found 4527 images belonging to 2 classes.
# Found 1131 images belonging to 2 classes.
# Found 1483 images belonging to 2 classes.

# %% [markdown]
# # Displaying Data Samples and Adding Labels to both Classes

# %%
print(f" training data samples :  {train_data_gen.samples} {train_data_gen.class_indices}")
print(f" testing data samples : {test_data_gen.samples} {test_data_gen.class_indices}")
# Out:
#  training data samples :  4527 {'DROWSY': 0, 'NATURAL': 1}
#  testing data samples : 1483 {'DROWSY': 0, 'NATURAL': 1}

# %% [markdown]
# # CNN Model for Drowsiness Classification

# %%
# Import required modules from Keras
from tensorflow.keras import models
from tensorflow.keras import layers

# Build a sequential CNN model
model = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),  # Convolutional layer: 32 filters of size 3x3, ReLU activation
    layers.MaxPool2D((2,2)),    # Max pooling layer: reduces spatial dimensions by 2

    layers.Flatten(),    # Flatten the 2D feature maps into a 1D vector

    layers.Dense(64, activation='relu'), # Fully connected (dense) layer with 64 units and ReLU activation

    layers.Dense(1, activation='sigmoid') # Output layer for binary classification: 1 neuron with sigmoid activation
])

model.compile(optimizer='adam',             # Optimizer: Adam (adaptive learning rate)
              loss='binary_crossentropy',   # Loss: Binary cross-entropy for binary output
              metrics=['accuracy'])         # Track accuracy during training

# Print model architecture summary
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-05-07 19:14:14.855352: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 394272)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │      25,233,472 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 25,234,433 (96.26 MB)
#  Trainable params: 25,234,433 (96.26 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Train the CNN Model on Image Data

# %%
# Fit the model using the training and validation generators
history = model.fit(
    train_data_gen, # Generator for training data (with augmentation)
    steps_per_epoch= train_data_gen.samples // train_data_gen.batch_size,  # Number of batches per training epoch
    epochs=10, # Total number of training epochs
    validation_data = val_data_gen,  # Generator for validation data
    validation_steps = val_data_gen.samples // val_data_gen.batch_size   # Validation batches per epoch
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.5577 - loss: 2.1502 - val_accuracy: 0.5295 - val_loss: 0.7549
# Epoch 2/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 982us/step - accuracy: 0.7500 - loss: 0.5295 - val_accuracy: 0.8182 - val_loss: 0.5549
# Epoch 3/10
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 193s 1s/step - accuracy: 0.7465 - loss: 0.5249 - val_accuracy: 0.5250 - val_loss: 0.8807
# Epoch 4/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 876us/step - accuracy: 0.6562 - loss: 0.5703 - val_accuracy: 0.5455 - val_loss: 0.8939
# Epoch 5/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.7601 - loss: 0.4812 - val_accuracy: 0.5437 - val_loss: 0.8322
# Epoch 6/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 935us/step - accuracy: 0.8125 - loss: 0.4895 - val_accuracy: 0.3636 - val_loss: 1.0634
# Epoch 7/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.7703 - loss: 0.4780 - val_accuracy: 0.6098 - val_loss: 0.7234
# Epoch 8/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 871us/step - accuracy: 0.7500 - loss: 0.5857 - val_accuracy: 0.7273 - val_loss: 0.6014
# Epoch 9/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.7923 - loss: 0.4530 - val_accuracy: 0.5857 - val_loss: 0.7690
# Epoch 10/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 930us/step - accuracy: 0.7188 - loss: 0.5395 - val_accuracy: 0.4545 - val_loss: 0.8900

# %% [markdown]
# # Plot Training vs Validation Loss Over Epochs

# %%
plt.plot(history.history['loss'], label='training loss')    # Training loss per epoch
plt.plot(history.history['val_loss'], label='validation loss')  # Validation loss per epoch
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation vs Training Loss')
plt.legend()
plt.show()   # Display the plot

# %% [markdown]
# # Plot Training vs Validation Accuracy Over Epochs

# %%
plt.plot(history.history['accuracy'], label='validation accuracy')  # Training accuracy over epochs
plt.plot(history.history['val_accuracy'], label='validation accuracy') # Validation accuracy over epochs
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title("Validation Vs Training Accuracy")
plt.show()  # Display the plot

# %% [markdown]
# # 🛑 Add EarlyStopping Callback to Training

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Stop training if validation loss doesn't improve for 3 consecutive epochs
early_stop = EarlyStopping(
    monitor='val_loss',       # What to monitor (can also be 'val_accuracy')
    patience=3,               # Number of epochs with no improvement to wait
    restore_best_weights=True  # Restore the best model weights seen during training
)

# Train the model with EarlyStopping
history = model.fit(
    train_data_gen,
    steps_per_epoch=train_data_gen.samples // train_data_gen.batch_size,
    epochs=20,  # You can still set a higher max epoch
    validation_data=val_data_gen,
    validation_steps=val_data_gen.samples // val_data_gen.batch_size,
    callbacks=[early_stop]  # EarlyStopping
)
# Out:
# Epoch 1/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - accuracy: 0.7887 - loss: 0.4527 - val_accuracy: 0.5955 - val_loss: 0.8400
# Epoch 2/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7812 - loss: 0.4903 - val_accuracy: 0.5455 - val_loss: 1.6156
# Epoch 3/20
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 205s 1s/step - accuracy: 0.8004 - loss: 0.4245 - val_accuracy: 0.6330 - val_loss: 0.7337
# Epoch 4/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9375 - loss: 0.3391 - val_accuracy: 0.7273 - val_loss: 0.5831
# Epoch 5/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.8064 - loss: 0.4205 - val_accuracy: 0.5946 - val_loss: 0.7558
# Epoch 6/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7188 - loss: 0.4823 - val_accuracy: 0.7273 - val_loss: 0.5693
# Epoch 7/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - accuracy: 0.8092 - loss: 0.4083 - val_accuracy: 0.6455 - val_loss: 0.7066
# Epoch 8/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8125 - loss: 0.3835 - val_accuracy: 0.8182 - val_loss: 0.4173
# Epoch 9/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.8145 - loss: 0.4012 - val_accuracy: 0.6696 - val_loss: 0.6482
# Epoch 10/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 893us/step - accuracy: 0.8438 - loss: 0.3606 - val_accuracy: 0.4545 - val_loss: 0.5841
# Epoch 11/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 201s 1s/step - accuracy: 0.8207 - loss: 0.3850 - val_accuracy: 0.6812 - val_loss: 0.6500

# %%
plt.plot(history.history['loss'], label='training loss')    # Training loss per epoch
plt.plot(history.history['val_loss'], label='validation loss')  # Validation loss per epoch
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation vs Training Loss')
plt.legend()
plt.show()   # Display the plot

# %%
plt.plot(history.history['accuracy'], label='validation accuracy')  # Training accuracy over epochs
plt.plot(history.history['val_accuracy'], label='validation accuracy') # Validation accuracy over epochs
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title("Validation Vs Training Accuracy")
plt.show()  # Display the plot

# %% [markdown]
# # Evaluate the trained model using the test dataset

# %%
# Evaluate the trained model using the test dataset
loss , accuracy = model.evaluate(test_data_gen)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 14s 304ms/step - accuracy: 0.7890 - loss: 0.4473

# %% [markdown]
# # Prepare Test Data Generator

# %%
test_data = test_data_generator.flow_from_directory(
    test_path,
    target_size=(224,224),
    batch_size=32,
    class_mode='binary',
    shuffle=False       # Disable shuffling for accurate label-prediction alignment
)
# Out:
# Found 1483 images belonging to 2 classes.

# %% [markdown]
# # Generate Predictions and Prepare for Evaluation

# %%
# Get true labels
y_true = test_data.classes  # or val_data.classes

# Predict probabilities
y_probs = model.predict(test_data)

# Convert to binary class predictions (0 or 1)
y_pred = (y_probs > 0.5).astype(int).reshape(-1)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 14s 293ms/step

# %% [markdown]
# # 🔷 Plot Confusion Matrix for Model Predictions

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Display it
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=test_data.class_indices.keys())
disp.plot(cmap='Blues')
plt.title('Confusion Matrix - Drowsy vs Natural')
plt.show()

# %% [markdown]
# # 📝 Generate and Display Classification Report

# %%
from sklearn.metrics import classification_report

# Create the classification report using true and predicted labels
report= classification_report(y_true, y_pred, target_names=test_data.class_indices.keys())


print("🔍 Classification Report:\n")
print(report)
# Out:
# 🔍 Classification Report:
#
#               precision    recall  f1-score   support
#
#       DROWSY       0.79      0.77      0.78       757
#      NATURAL       0.76      0.79      0.78       726
#
#     accuracy                           0.78      1483
#    macro avg       0.78      0.78      0.78      1483
# weighted avg       0.78      0.78      0.78      1483
